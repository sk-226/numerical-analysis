# %%
import pandas as pd

# %%
df = pd.read_csv("../inputs/runs.csv")
df.head()
# Out:
#    matrix_name  matrix_size   nnz solver     tolerance  max_iters   rhs  \
# 0  HB/1138_bus         1138  4054     cg  1.000000e-12       2276  ones
# 1  HB/1138_bus         1138  4054    pcg  1.000000e-12       2276  ones
# 2  HB/1138_bus         1138  4054    pcg  1.000000e-12       2276  ones
# 3  HB/1138_bus         1138  4054    pcg  1.000000e-12       2276  ones
# 4  HB/1138_bus         1138  4054    pcg  1.000000e-12       2276  ones
#
#   precision  prec                                            prec_kv  ...  \
# 0    double  none                                                NaN  ...
# 1    double    ic                                      ictype=nofill  ...
# 2    double    ic                                      ictype=nofill  ...
# 3    double    ic  ictype=nofill,diagcomp=max(sum(abs(A),2)./diag...  ...
# 4    double    ic  ictype=nofill,diagcomp=max(sum(abs(A),2)./diag...  ...
#
#   construction_time  is_converged   iters  true_relres_2  final_relres_2  \
# 0          0.000000             0  2276.0   8.905753e-09    8.905720e-09
# 1          0.002130             1   153.0   6.943319e-13    6.963629e-13
# 2          0.001326             1   153.0   6.943319e-13    6.963629e-13
# 3          0.000598             1   152.0   9.276991e-13    9.269899e-13
# 4          0.000482             1   152.0   9.276991e-13    9.269899e-13
#
#    final_relerr_2  final_relerr_A  solve_time    solve_status condition_number
# 0    5.153921e-08    3.003619e-08    0.059298  max_iterations     1.228416e+07
# 1    3.322234e-12    3.202435e-12    0.014439     reached_tol     1.228416e+07
# 2    3.322234e-12    3.202435e-12    0.007529     reached_tol     1.228416e+07
# 3    4.749755e-12    4.915714e-12    0.004980     reached_tol     1.228416e+07
# 4    4.749755e-12    4.915714e-12    0.005194     reached_tol     1.228416e+07
#
# [5 rows x 21 columns]

# %%
prec_unknown_matrix_names = df.query("solve_status == 'prec_unknown'")["matrix_name"].unique()
print(prec_unknown_matrix_names)
print("COUNT: ", len(prec_unknown_matrix_names))
# Out:
# ['Bates/Chem97ZtZ' 'HB/bcsstm02' 'HB/bcsstm05' 'HB/bcsstm06' 'HB/bcsstm08'
#  'HB/bcsstm09' 'HB/bcsstm11' 'HB/bcsstm19' 'HB/bcsstm20' 'HB/bcsstm21'
#  'HB/bcsstm22' 'HB/bcsstm23' 'HB/bcsstm24' 'HB/bcsstm25' 'HB/bcsstm26'
#  'Boeing/bcsstm39' 'JGD_BIBD/bibd_81_2' 'Pothen/bodyy4' 'Pothen/bodyy5'
#  'Pothen/bodyy6' 'Norris/fv1' 'Norris/fv2' 'GHS_psdef/jnlbrng1'
#  'Pothen/mesh1e1' 'Pothen/mesh1em1' 'Pothen/mesh1em6' 'Pothen/mesh2e1'
#  'Pothen/mesh2em5' 'Pothen/mesh3e1' 'Pothen/mesh3em5' 'GHS_psdef/minsurfo'
#  'HB/nos6' 'GHS_psdef/obstclae' 'Oberwolfach/t2dal_e' 'Oberwolfach/t3dl_e'
#  'GHS_psdef/torsion1']
# COUNT:  36

# %%
prec_unknown_df = df.query("solve_status == 'prec_unknown'")
for matrix_name in prec_unknown_matrix_names:
    print(matrix_name + ":")
    unique_converged = df[df["matrix_name"] == matrix_name]["is_converged"].unique()
    print(unique_converged)
# Out:
# Bates/Chem97ZtZ:
# [1 0]
# HB/bcsstm02:
# [1 0]
# HB/bcsstm05:
# [1 0]
# HB/bcsstm06:
# [1 0]
# HB/bcsstm08:
# [1 0]
# HB/bcsstm09:
# [1 0]
# HB/bcsstm11:
# [1 0]
# HB/bcsstm19:
# [1 0]
# HB/bcsstm20:
# [1 0]
# HB/bcsstm21:
# [1 0]
# HB/bcsstm22:
# [1 0]
# HB/bcsstm23:
# [1 0]
# HB/bcsstm24:
# [1 0]
# HB/bcsstm25:
# [0 1]
# HB/bcsstm26:
# [1 0]
# Boeing/bcsstm39:
# [1 0]
# JGD_BIBD/bibd_81_2:
# [1 0]
# Pothen/bodyy4:
# [1 0]
# Pothen/bodyy5:
# [1 0]
# Pothen/bodyy6:
# [1 0]
# Norris/fv1:
# [1 0]
# Norris/fv2:
# [1 0]
# GHS_psdef/jnlbrng1:
# [1 0]
# Pothen/mesh1e1:
# [1 0]
# Pothen/mesh1em1:
# [1 0]
# Pothen/mesh1em6:
# [1 0]
# Pothen/mesh2e1:
# [1 0]
# Pothen/mesh2em5:
# [1 0]
# Pothen/mesh3e1:
# [1 0]
# Pothen/mesh3em5:
# [1 0]
# GHS_psdef/minsurfo:
# [1 0]
# HB/nos6:
# [0 1]
# GHS_psdef/obstclae:
# [1 0]
# Oberwolfach/t2dal_e:
# [0 1]
# Oberwolfach/t3dl_e:
# [1 0]
# GHS_psdef/torsion1:
# [1 0]
